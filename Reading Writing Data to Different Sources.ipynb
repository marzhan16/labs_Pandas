# %%
import pandas as pd
df_public = pd.read_csv('survey_results_public.csv', index_col='Respondent')
df_schema = pd.read_csv('survey_results_schema.csv', index_col= 'Column')

# %%
filt = df_public['Country'] == 'India'
df_india = df_public.loc[filt].head()
df_india
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
df_india.to_csv('modified1.csv')

# %%
df_india.to_csv('modified.tsv', sep='\t')

# %%
#df_india.to_excel('excel_file.xlsx')

# %%
#test = pd.read_excel('excel_file.xlsx', index_col='Respondent')
#test

# %%
df_india.to_json('modified.json')

# %%
test1 = pd.read_json('modified.json')

# %%
test1
# Out:
#                                 MainBranch Hobbyist  \
# 8              I code primarily as a hobby      Yes
# 10          I am a developer by profession      Yes
# 15  I am a student who is learning to code      Yes
# 50          I am a developer by profession      Yes
# 65          I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 8      Less than once per year
# 10  Once a month or more often
# 15                       Never
# 50  Once a month or more often
# 65                       Never
#
#                                            OpenSource  \
# 8   OSS is, on average, of HIGHER quality than pro...
# 10  OSS is, on average, of HIGHER quality than pro...
# 15  OSS is, on average, of HIGHER quality than pro...
# 50  OSS is, on average, of LOWER quality than prop...
# 65                                               None
#
#                             Employment Country         Student  \
# ...

# %%
#from sqlalchemy import create_engine
#import psycopg2

# %%
#engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
#df_india.to_sql('sample_data', engine, if_exists = 'replace')

# %%
#sql_df = pd.read_sql('sample_data', engine, index_col = 'Respondent')
#sql_df

# %%
#sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col = 'Respondent')
#sql_df

# %%
post = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
post
# Out:
#                                               title  \
# 0                                   My Updated Post
# 1                                     A Second Post
# 2                      Top 5 Programming Lanaguages
# 3                      Sublime Text Tips and Tricks
# 4                                  Best Python IDEs
# 5                Flask vs Django - Which Is Better?
# 6         You Won't Believe These Clickbait Titles!
# 7         These Beers Will Improve Your Programming
# 8                          List of PyCon 2018 Talks
# 9     How Dogs in the Workplace Boosts Productivity
# 10                    The Best Programming Podcasts
# 11                         Tips for Public Speaking
# 12              Best Programmers Throughout History
# 13                  How To Create A YouTube Channel
# 14                           How I Record My Videos
# 15                               Python and Physics
# 16            Just A Few More Healines Should Do It
# ...
