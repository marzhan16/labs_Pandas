# %%
people = {
    'name' : ['Azamat', 'Zhuldyz', 'Azamat', 'Kamila', 'Aruzhan'],
    'surname' : ['Tolegazinov', 'Gabitova', 'Bolatov', 'Hamitova', 'Duisen'],
    'email' : ['aza.tol@gamil.com', 'zhuldyz99@gmail.com', 'azamat.g@mail.ru', 'kami.hamitova@yandex.ru', 'aru.duisen@gmail.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       name      surname                    email
# 0   Azamat  Tolegazinov        aza.tol@gamil.com
# 1  Zhuldyz     Gabitova      zhuldyz99@gmail.com
# 2   Azamat      Bolatov         azamat.g@mail.ru
# 3   Kamila     Hamitova  kami.hamitova@yandex.ru
# 4  Aruzhan       Duisen     aru.duisen@gmail.com

# %%
df.sort_values(by = 'name')
# Out:
#       name      surname                    email
# 4  Aruzhan       Duisen     aru.duisen@gmail.com
# 0   Azamat  Tolegazinov        aza.tol@gamil.com
# 2   Azamat      Bolatov         azamat.g@mail.ru
# 3   Kamila     Hamitova  kami.hamitova@yandex.ru
# 1  Zhuldyz     Gabitova      zhuldyz99@gmail.com

# %%
df.sort_values(by = 'surname', ascending = False)
# Out:
#       name      surname                    email
# 0   Azamat  Tolegazinov        aza.tol@gamil.com
# 3   Kamila     Hamitova  kami.hamitova@yandex.ru
# 1  Zhuldyz     Gabitova      zhuldyz99@gmail.com
# 4  Aruzhan       Duisen     aru.duisen@gmail.com
# 2   Azamat      Bolatov         azamat.g@mail.ru

# %%
df.sort_values(by = ['surname', 'name'])
# Out:
#       name      surname                    email
# 2   Azamat      Bolatov         azamat.g@mail.ru
# 4  Aruzhan       Duisen     aru.duisen@gmail.com
# 1  Zhuldyz     Gabitova      zhuldyz99@gmail.com
# 3   Kamila     Hamitova  kami.hamitova@yandex.ru
# 0   Azamat  Tolegazinov        aza.tol@gamil.com

# %%
df.sort_values(by = ['surname', 'name'], ascending = [False, True], inplace = True)

# %%
df
# Out:
#       name      surname                    email
# 0   Azamat  Tolegazinov        aza.tol@gamil.com
# 3   Kamila     Hamitova  kami.hamitova@yandex.ru
# 1  Zhuldyz     Gabitova      zhuldyz99@gmail.com
# 4  Aruzhan       Duisen     aru.duisen@gmail.com
# 2   Azamat      Bolatov         azamat.g@mail.ru

# %%
df.sort_index(inplace= True)

# %%
df
# Out:
#       name      surname                    email
# 0   Azamat  Tolegazinov        aza.tol@gamil.com
# 1  Zhuldyz     Gabitova      zhuldyz99@gmail.com
# 2   Azamat      Bolatov         azamat.g@mail.ru
# 3   Kamila     Hamitova  kami.hamitova@yandex.ru
# 4  Aruzhan       Duisen     aru.duisen@gmail.com

# %%
df['name'].sort_values()
# Out:
# 4    Aruzhan
# 0     Azamat
# 2     Azamat
# 3     Kamila
# 1    Zhuldyz
# Name: name, dtype: object

# %%
df_public = pd.read_csv('survey_results_public.csv')
df_schema = pd.read_csv('survey_results_schema.csv')

# %%
df_public.sort_values(by = ['Country', 'ConvertedComp'], ascending = [True, False], inplace = True)

# %%
df_public[['Country', 'ConvertedComp']].head(50)
# Out:
#                   Country  ConvertedComp
# 7056          Afghanistan        14364.0
# 8112          Afghanistan         1596.0
# 719           Afghanistan            0.0
# 6391          Afghanistan            NaN
# 7323          Afghanistan            NaN
# 3771              Albania       114550.0
# 6688              Albania        60000.0
# 2324              Albania        22080.0
# 1946              Albania        11040.0
# 6181              Albania            NaN
# 5897              Algeria        23376.0
# 1536              Algeria         9144.0
# 6506              Algeria         8640.0
# 4373              Algeria         6612.0
# 1098              Algeria            NaN
# 3060              Algeria            NaN
# 3286              Algeria            NaN
# 3441              Algeria            NaN
# 3600              Algeria            NaN
# 4154              Algeria            NaN
# 4302              Algeria            NaN
# 4363              Algeria            NaN
# ...

# %%
df_public['ConvertedComp'].nlargest(10)
# Out:
# 57      2000000.0
# 101     2000000.0
# 164     2000000.0
# 434     2000000.0
# 450     2000000.0
# 489     2000000.0
# 537     2000000.0
# 767     2000000.0
# 786     2000000.0
# 1228    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df_public.nlargest(10, 'ConvertedComp')
# Out:
#       Respondent                      MainBranch Hobbyist  \
# 57            58  I am a developer by profession      Yes
# 101          102  I am a developer by profession       No
# 164          166  I am a developer by profession      Yes
# 434          436  I am a developer by profession      Yes
# 450          452  I am a developer by profession      Yes
# 489          491  I am a developer by profession      Yes
# 537          539  I am a developer by profession       No
# 767          770  I am a developer by profession      Yes
# 786          789  I am a developer by profession      Yes
# 1228        1232  I am a developer by profession       No
#
#                                             OpenSourcer  \
# 57                           Once a month or more often
# 101                                               Never
# 164                             Less than once per year
# 434                             Less than once per year
# ...

# %%
df_public.nsmallest(5, 'ConvertedComp')
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 719          722                     I am a developer by profession       No
# 1678        1685                     I am a developer by profession      Yes
# 1101        1105                     I am a developer by profession       No
# 6312        6338                     I am a developer by profession      Yes
# 4127        4144  I am not primarily a developer, but I write co...      Yes
#
#                                             OpenSourcer  \
# 719   Less than once a month but more than once per ...
# 1678  Less than once a month but more than once per ...
# 1101                                              Never
# 6312                         Once a month or more often
# 4127  Less than once a month but more than once per ...
#
#                                              OpenSource  \
# 719   The quality of OSS and closed source software ...
# ...

# %%
df_public['ConvertedComp'].nsmallest(5)
# Out:
# 719     0.0
# 1678    0.0
# 1101    0.0
# 6312    0.0
# 4127    0.0
# Name: ConvertedComp, dtype: float64
